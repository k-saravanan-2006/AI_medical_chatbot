# %% [markdown]
# ## Install and import required packages

# %%
# %pip install langchain-core langchain-community langchain-text-splitters chromadb
# Out:
# Collecting langchain-core
#   Using cached langchain_core-1.2.9-py3-none-any.whl (496 kB)
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Collecting langchain-text-splitters
#   Using cached langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Collecting chromadb
#   Using cached chromadb-1.4.1-cp39-abi3-win_amd64.whl (21.4 MB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-core) (0.6.9)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-core) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-core) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-core) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-community) (2.32.5)
# Collecting langchain-classic<2.0.0,>=1.0.0
#   Using cached langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-community) (2.0.46)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (14.3.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (5.4.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl (19 kB)
# Collecting jsonschema>=4.19.0
#   Using cached jsonschema-4.26.0-py3-none-any.whl (90 kB)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (5.0.0)
# Collecting opentelemetry-sdk>=1.2.0
#   Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (0.40.0)
# Requirement already satisfied: importlib-resources in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (6.5.2)
# Collecting tokenizers>=0.13.2
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: colorama in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from build>=1.0.3->chromadb) (2.4.0)
# Requirement already satisfied: pyproject_hooks in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: certifi in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from httpx>=0.27.0->chromadb) (2026.1.4)
# Requirement already satisfied: anyio in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: httpcore==1.* in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: requests-oauthlib in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: sympy in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: protobuf in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: flatbuffers in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: coloredlogs in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: greenlet>=1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.1)
# Collecting huggingface-hub<2.0,>=0.16.4
#   Using cached huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: typer-slim in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.21.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: filelock in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.3)
# Requirement already satisfied: zipp>=3.20 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\swetha k\desktop\sairam clg\programs\3.python\gen ai\ai_medical_chatbot\env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Installing collected packages: jsonschema, opentelemetry-sdk, huggingface-hub, tokenizers, opentelemetry-exporter-otlp-proto-grpc, langchain-core, langchain-text-splitters, chromadb, langchain-classic, langchain-community
# Successfully installed chromadb-1.4.1 huggingface-hub-1.4.1 jsonschema-4.26.0 langchain-classic-1.0.1 langchain-community-0.4.1 langchain-core-1.2.9 langchain-text-splitters-1.1.0 opentelemetry-exporter-otlp-proto-grpc-1.39.1 opentelemetry-sdk-1.39.1 tokenizers-0.22.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_core.prompts import PromptTemplate

from langchain_community.embeddings import FastEmbedEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_community.llms import CTransformers
